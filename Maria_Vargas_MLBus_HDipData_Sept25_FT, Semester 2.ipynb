# %% [markdown]
# ### Download Data from yahoo finance

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import yfinance as yf

# %%
# Define the ticker symbol for S&P 500 (^GSPC)
# For example, https://finance.yahoo.com/quote/%5EGSPC/history/?period1=1569174385&period2=1727027123
ticker_symbol = "AAPL"

# Download historical data
data = yf.download(ticker_symbol, period="10y")

# Save to CSV
data.to_csv('AAPL_10y_finance_data.csv')

print("Data downloaded and saved as AAPL_10y_finance_data.csv")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Data downloaded and saved as AAPL_10y_finance_data.csv

# %%
import yfinance as yf

data = yf.download(
    "AAPL",
    start="2016-03-30",
    end="2026-03-30"
)

print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-03-30  24.813198  25.007971  24.595777  24.607102  182404400
# 2016-03-31  24.684105  24.890203  24.659192  24.849436  103553600
# 2016-04-01  24.910585  24.912851  24.505185  24.636544  103496000
# 2016-04-04  25.166510  25.408844  24.974000  25.007972  149424800
# 2016-04-05  24.869820  25.078183  24.781492  24.801877  106314800

# %%
# Save the data to a CSV file
data.to_csv('AAPL_10y_data.csv')

print("Data downloaded and saved as AAPL_10y_data.csv")
# Out:
# Data downloaded and saved as AAPL_10y_data.csv

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore') # We can suppress the warnings

# %%
aapl=pd.read_csv("AAPL_10y_data.csv")

# %%
# Display first 5 records
aapl.head(30)
# Out:
#          Price               Close                High                 Low  \
# 0       Ticker                AAPL                AAPL                AAPL
# 1         Date                 NaN                 NaN                 NaN
# 2   2016-03-30   24.81319808959961  25.007971419075243  24.595777060212356
# 3   2016-03-31  24.684104919433594  24.890202967996302  24.659191930532415
# 4   2016-04-01  24.910585403442383  24.912850691865195   24.50518517119843
# 5   2016-04-04    25.1665096282959   25.40884365418212  24.973999852742512
# 6   2016-04-05   24.86981964111328  25.078182984908835  24.781492396815462
# 7   2016-04-06   25.13027000427246   25.13480058080752  24.731663936712053
# 8   2016-04-07  24.582181930541992  25.007964445030883   24.48706058069473
# 9   2016-04-08  24.609365463256836  24.860757162220555  24.498388803456823
# 10  2016-04-11  24.690898895263672  25.051003723810304  24.647868783004864
# ...

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2516 non-null   object
#  1   Close   2515 non-null   object
#  2   High    2515 non-null   object
#  3   Low     2515 non-null   object
#  4   Open    2515 non-null   object
#  5   Volume  2515 non-null   object
# dtypes: object(6)
# memory usage: 118.1+ KB

# %%
aapl.shape
# Out:
# (2516, 6)

# %%
# Plot the data present in the dataframe
aapl.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Plot the data present in the dataframe
# ----> 2 aapl.plot()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
# Importing required Python libraries
import pandas as pd
from tbats import TBATS
import matplotlib.pyplot as plt

# Load the dataset from the website
url = "https://finance.yahoo.com/quote/CSV/history/"
df = pd.read_csv(url, header=0, parse_dates=[0], index_col=0)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# ...

# %%
# Display first few rows of the dataset
print(df.head())

# Plot the original data
plt.figure(figsize = (10, 6))
plt.plot(df.index, df['Passengers'], marker = 'o', linestyle = '-')
plt.title('Airline Passengers')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.grid(True)
plt.show()

# Fit TBATS model
model = TBATS(seasonal_periods = (12, 24))
fit = model.fit(df['Passengers'])

# Generate forecast
forecast = fit.forecast(steps=12)  # Forecast for the next 12 months

# Generate dates for the forecast
last_date = df.index[-1]
forecast_dates = pd.date_range(start=last_date, periods=13, freq='MS')[1:]  # Exclude the first date

# Plot the forecast
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Passengers'], marker='o', linestyle='-', label='Actual')
plt.plot(forecast_dates, forecast, marker='o', linestyle='-', label='Forecast')
plt.title('Airline Passengers Forecast')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the data present in the dataframe
air_passengers.plot()

# %% [markdown]
# Las preguntas del proyecto podrían ser: (esta es una pequeña muestra sugerida; otras preguntas podrían ser más apropiadas para su proyecto)
#
# • ¿Cómo medir la similitud o disimilitud entre diferentes clústeres?
#
# • ¿Qué solución de agrupamiento prefiere y por qué?
#
# • ¿Cómo analizar e investigar la tasa de inflación de un producto específico a partir del conjunto de datos de series temporales proporcionado?
#
# i. Una introducción precisa, la motivación, la descripción del dominio del problema, los objetivos del proyecto y la justificación del conjunto de datos elegido en las áreas mencionadas anteriormente.
#
# (15 puntos)
# ii. ¿Qué algoritmos de agrupamiento consideraría para la segmentación y por qué? Implemente las soluciones y analice las diferencias entre el índice de silueta y el índice de Davies-Bouldin en el contexto del agrupamiento. Compare los resultados obtenidos con dos algoritmos de agrupamiento cualesquiera, utilizando el conjunto de datos que haya elegido.
#
# (30 puntos)
# iii. Implemente sus soluciones y analice qué conclusiones puede extraer de la exploración inicial de los datos de series temporales, basándose en los temas proporcionados. Describa cualquier tendencia, estacionalidad o anomalía observada. ¿Cómo determinó los parámetros adecuados (p, d, q) para el modelo ARIMA/SARIMA? Evalúe el rendimiento del modelo ARIMA/SARIMA en la predicción de valores futuros, destacando sus fortalezas y limitaciones con base en el conjunto de datos elegido.
#
# (30 puntos)
# iv. Interprete y justifique los resultados según la especificación del problema o los objetivos del proyecto, utilizando visualizaciones adecuadas. Los comentarios y la descripción del código Python, así como las conclusiones del proyecto, deben especificarse en el informe y en el cuaderno Jupyter. Las citas y referencias deben seguir el estilo Harvard. Deberá grabar una presentación en video para explicar y justificar su informe y el código en el cuaderno Jupyter. El video no debe exceder los 5 minutos de duración y no se permite el uso de voces o agentes generados por IA. El formato de grabación de video se menciona a continuación.
#
#
# Nota: Puede elegir dos conjuntos de datos diferentes para la tarea (ii) o la tarea (iii) por separado, o un solo conjunto de datos para ambas tareas, según la justificación de su proyecto.
